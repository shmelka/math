# %%
#Дополните код расчетом коэффициента корреляции x и y по формуле
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100
r = 0.7
x = np.random.rand(n)
y = r * x + (1 - r) * np.random.rand(n)
plt.plot(x, y, 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

a = (np.sum(x) * np.sum(y) - n * np.sum(x * y)) / (np.sum(x) * np.sum(x) - n * np.sum(x * x))
b = (np.sum(y) - a * np.sum(x)) / n

A = np.vstack([x, np.ones(len(x))]).T
a1, b1 = np.linalg.lstsq(A, y)[0]

print(a, b)
print(a1, b1)
plt.plot([0, 1], [b, a + b])
plt.show()

R = np.sum((x - np.mean(x)) * (y - np.mean(y))) / np.sqrt(np.sum(x - np.mean(x))**2 * np.sum(y - np.mean(y))**2)
print(f'Коэффициент корреляции: {R}')
# Out:
# 0.6804843488374676 0.17289990196405852
# 0.6804843488374672 0.1728999019640587
# C:\Users\elagi\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# Коэффициент корреляции: 1.29515370409069e+30
