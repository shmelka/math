# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
#y(x) = k∙cos(x – a) + b
k = 5
x = np.linspace(-5, 5, 100)
a = 2
b = 4
y = k * (x - a) + b
plt.plot(x, y)

k = 2
a = 8
b = 15
y = k * (x - a) + b
plt.plot(x, y)

k = 15
a = 3
b = 30
y = k * (x - a) + b
plt.plot(x, y)

plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
