# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import math
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

# %%
#y(x) = k∙cos(x – a) + b
k = 5
x = np.linspace(-5, 5, 100)
a = 2
b = 4
y = k * (x - a) + b
plt.plot(x, y)

k = 2
a = 8
b = 15
y = k * (x - a) + b
plt.plot(x, y)

k = 15
a = 3
b = 30
y = k * (x - a) + b
plt.plot(x, y)

plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X, Y = np.meshgrid(X, Y)
Z = 2 * X**2 - 4 * Y**2
ax.plot_wireframe(X, Y, Z)

X2 = np.arange(-5, 5, 0.5)
Y2 = np.arange(-5, 5, 0.5)
X2, Y2 = np.meshgrid(X2, Y2)
Z2 = 2 * X2**2 + 2 * 5 * X2 * Y2 + 3 * Y2**2 + 2 * 4 * X2 + 2 * 4 * Y2 + 150
ax.plot_wireframe(X2, Y2, Z2, color='red')
